# %%
from processing import msevn

msevn.configure_mpl()

# %%
datadir = './lpic/output'
imagesize = 1600

fig = msevn.lpic_plot.density(datadir=datadir, imagesize=imagesize, xlim=(0, 250), xstep=1)

# %%
msevn.lpic_est.thickness_transition_layer(datadir=datadir, imagesize=imagesize, nm_per_pixel=250 / 1600)
# Out:
# 4.91640625

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

x = np.array([5, 9, 15, 20, 30, 40, 50, 60])
y10 = np.array([4.287, 4.561, 4.699, 4.7387, 4.808, 4.872, 4.883, 4.892])
#y1 = np.array([6.067, 6.3941, 6.4797, 6.5148, 6.587, 6.7026])


fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(x=x, y=y10 / (2*x), s=130, marker='^', color='purple', label=r'$\lambda=\lambda_{10}$')
#sns.scatterplot(x=x, y=y1 / (2*x), s=130, marker='v', color='blue', label=r'$\lambda=\lambda_{L}$')

ax.set_xlabel(r'$a$, $\rm{nm}$', labelpad=15)
ax.set_ylabel(r'$h_{tr}\:\:/\:\:2a$', labelpad=15)

#fig.savefig('../tex/components/img/lpic/htr_over_2a_a.pdf', bbox_inches='tight')
# Out:
# Text(0, 0.5, '$h_{tr}\\:\\:/\\:\\:2a$')
