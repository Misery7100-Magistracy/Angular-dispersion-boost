# %%
from processing import msevn
import os
import pandas as pd

msevn.configure_mpl()

# %%
root = './matlab/output/flat'

files = os.listdir(root)

# %%
ext_circ = msevn.mesh_generator.target_plot.project_2d(gap=83*2, edge=16, mult=10, angle=15)
ext_circ = pd.DataFrame(ext_circ, columns=['x', 'y', 'z', 'r'])

# %%
xz1 = msevn.MstmEngine(os.path.join(root, files[1]))
fig, ax, bbea = xz1.plot_field(
    trim=20,
    figsize=(10, 10),
    target=dict(plot=True, color='magenta', linewidth=0.4, alpha=0.7),
    xtick=3000,
    ytick=2000,
    external_circles=ext_circ,
)
ax.grid(alpha=0.1, color='white')

# fig.savefig(f'../tex/components/img/celes/Es_20nm_15deg_10harm.pdf', bbox_inches='tight')

# %%
xz0 = msevn.MstmEngine(os.path.join(root, files[0]))
fig, ax, bbea = xz0.plot_field(
    trim=20,
    figsize=(10, 10),
    target=dict(plot=True, color='magenta', linewidth=0.4, alpha=0.7),
    xtick=3000,
    ytick=2000,
    external_circles=ext_circ,
    vmax=0.14,
    factor=0.08,
    bartick=0.02
)
ax.grid(alpha=0.1, color='white')

fig.savefig(f'../tex/components/img/celes/Es_20nm_15deg_1harm.pdf', bbox_inches='tight')
# Out:
# Error in callback <function flush_figures at 0x7f8b52551dc0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=117'>118</a> if InlineBackend.instance().close_figures:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=118'>119</a>     # ignore the tracking, just draw and close all figures
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=119'>120</a>     try:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=120'>121</a>         return show(True)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=121'>122</a>     except Exception as e:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=122'>123</a>         # safely show traceback if in IPython, else raise
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=123'>124</a>         ip = get_ipython()
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=38'>39</a> try:
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=39'>40</a>     for figure_manager in Gcf.get_all_fig_managers():
# ---> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=40'>41</a>         display(
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=41'>42</a>             figure_manager.canvas.figure,
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=42'>43</a>             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=43'>44</a>         )
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=44'>45</a> finally:
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=45'>46</a>     show._to_draw = []
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=295'>296</a>     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=296'>297</a> else:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=297'>298</a>     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=298'>299</a>     if not format_dict:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=299'>300</a>         # nothing to display (e.g. _ipython_display_ took over)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=300'>301</a>         continue
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=175'>176</a> md = None
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=176'>177</a> try:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=177'>178</a>     data = formatter(obj)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=178'>179</a> except:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=179'>180</a>     # FIXME: log the exception
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=180'>181</a>     raise
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py?line=229'>230</a> if not kwsyntax:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py?line=230'>231</a>     args, kw = fix(args, kw, sig)
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py?line=231'>232</a> return caller(func, *(extras + args), **kw)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=219'>220</a> """show traceback on failed format call"""
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=220'>221</a> try:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=221'>222</a>     r = method(self, *args, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=222'>223</a> except NotImplementedError:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=223'>224</a>     # don't warn on NotImplementedErrors
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=224'>225</a>     return self._check_return(None, args[0])
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=336'>337</a>     pass
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=337'>338</a> else:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=338'>339</a>     return printer(obj)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=339'>340</a> # Finally look for special method names
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=340'>341</a> method = get_real_method(obj, self.print_method)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=147'>148</a>     from matplotlib.backend_bases import FigureCanvasBase
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=148'>149</a>     FigureCanvasBase(fig)
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=150'>151</a> fig.canvas.print_figure(bytes_io, **kw)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=151'>152</a> data = bytes_io.getvalue()
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=152'>153</a> if fmt == 'svg':
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2296'>2297</a> if bbox_inches:
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2297'>2298</a>     if bbox_inches == "tight":
# -> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2298'>2299</a>         bbox_inches = self.figure.get_tightbbox(
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2299'>2300</a>             renderer, bbox_extra_artists=bbox_extra_artists)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2300'>2301</a>         if pad_inches is None:
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2301'>2302</a>             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py:1632, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1628'>1629</a>     artists = bbox_extra_artists
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1630'>1631</a> for a in artists:
# -> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1631'>1632</a>     bbox = a.get_tightbbox(renderer)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1632'>1633</a>     if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1633'>1634</a>         bb.append(bbox)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py:355, in Artist.get_tightbbox(self, renderer)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=339'>340</a> def get_tightbbox(self, renderer):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=340'>341</a>     """
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=341'>342</a>     Like `.Artist.get_window_extent`, but includes any clipping.
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=342'>343</a>
#    (...)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=352'>353</a>         The enclosing bounding box (in figure pixel coordinates).
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=353'>354</a>     """
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=354'>355</a>     bbox = self.get_window_extent(renderer)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=355'>356</a>     if self.get_clip_on():
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=356'>357</a>         clip_box = self.get_clip_box()
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/patches.py:623, in Patch.get_window_extent(self, renderer)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/patches.py?line=621'>622</a> def get_window_extent(self, renderer=None):
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/patches.py?line=622'>623</a>     return self.get_path().get_extents(self.get_transform())
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py:628, in Path.get_extents(self, transform, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=624'>625</a> xys = []
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=625'>626</a> for curve, code in self.iter_bezier(**kwargs):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=626'>627</a>     # places where the derivative is zero can be extrema
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=627'>628</a>     _, dzeros = curve.axis_aligned_extrema()
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=628'>629</a>     # as can the ends of the curve
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=629'>630</a>     xys.append(curve([0, *dzeros, 1]))
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/bezier.py:300, in BezierSegment.axis_aligned_extrema(self)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/bezier.py?line=297'>298</a> roots = []
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/bezier.py?line=298'>299</a> for i, pi in enumerate(dCj.T):
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/bezier.py?line=299'>300</a>     r = np.roots(pi[::-1])
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/bezier.py?line=300'>301</a>     roots.append(r)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/bezier.py?line=301'>302</a>     dims.append(np.full_like(r, i))
#
# File <__array_function__ internals>:180, in roots(*args, **kwargs)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/lib/polynomial.py:254, in roots(p)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/lib/polynomial.py?line=251'>252</a>     A = diag(NX.ones((N-2,), p.dtype), -1)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/lib/polynomial.py?line=252'>253</a>     A[0,:] = -p[1:] / p[0]
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/lib/polynomial.py?line=253'>254</a>     roots = eigvals(A)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/lib/polynomial.py?line=254'>255</a> else:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/lib/polynomial.py?line=255'>256</a>     roots = NX.array([])
#
# File <__array_function__ internals>:180, in eigvals(*args, **kwargs)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py:1050, in eigvals(a)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=1047'>1048</a> _assert_stacked_2d(a)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=1048'>1049</a> _assert_stacked_square(a)
# -> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=1049'>1050</a> _assert_finite(a)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=1050'>1051</a> t, result_t = _commonType(a)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=1052'>1053</a> extobj = get_linalg_error_extobj(
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=1053'>1054</a>     _raise_linalgerror_eigenvalues_nonconvergence)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py:207, in _assert_finite(*arrays)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=204'>205</a> def _assert_finite(*arrays):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=205'>206</a>     for a in arrays:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=206'>207</a>         if not isfinite(a).all():
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/linalg/linalg.py?line=207'>208</a>             raise LinAlgError("Array must not contain infs or NaNs")
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/core/_methods.py:63, in _all(a, axis, dtype, out, keepdims, where)
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=59'>60</a> def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=60'>61</a>     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=61'>62</a>     if where is True:
# ---> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=62'>63</a>         return umr_all(a, axis, dtype, out, keepdims)
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=63'>64</a>     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
xz2 = msevn.MstmEngine(os.path.join(root, files[2]))
fig, ax, bbea = xz2.plot_field(
    trim=20,
    figsize=(10, 10),
    target=dict(plot=True, color='magenta', linewidth=0.4, alpha=0.7),
    xtick=3000,
    ytick=2000,
    external_circles=ext_circ
)
ax.grid(alpha=0.1, color='white')

fig.savefig(f'../tex/components/img/celes/Es_20nm_15deg_10harm_0.1nonreg.pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_63451/4043610541.py:12: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "extra_artists" which is no longer supported as of 3.3 and will become an error in 3.6
#   fig.savefig(f'../tex/components/img/celes/Es_20nm_15deg_10harm_0.1nonreg.pdf', bbox_inches='tight', extra_artists=bbea)
# Error in callback <function flush_figures at 0x7f8b52551dc0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=117'>118</a> if InlineBackend.instance().close_figures:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=118'>119</a>     # ignore the tracking, just draw and close all figures
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=119'>120</a>     try:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=120'>121</a>         return show(True)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=121'>122</a>     except Exception as e:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=122'>123</a>         # safely show traceback if in IPython, else raise
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=123'>124</a>         ip = get_ipython()
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=38'>39</a> try:
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=39'>40</a>     for figure_manager in Gcf.get_all_fig_managers():
# ---> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=40'>41</a>         display(
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=41'>42</a>             figure_manager.canvas.figure,
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=42'>43</a>             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=43'>44</a>         )
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=44'>45</a> finally:
#      <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py?line=45'>46</a>     show._to_draw = []
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=295'>296</a>     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=296'>297</a> else:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=297'>298</a>     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=298'>299</a>     if not format_dict:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=299'>300</a>         # nothing to display (e.g. _ipython_display_ took over)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/display_functions.py?line=300'>301</a>         continue
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=175'>176</a> md = None
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=176'>177</a> try:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=177'>178</a>     data = formatter(obj)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=178'>179</a> except:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=179'>180</a>     # FIXME: log the exception
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=180'>181</a>     raise
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py?line=229'>230</a> if not kwsyntax:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py?line=230'>231</a>     args, kw = fix(args, kw, sig)
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/decorator.py?line=231'>232</a> return caller(func, *(extras + args), **kw)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=219'>220</a> """show traceback on failed format call"""
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=220'>221</a> try:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=221'>222</a>     r = method(self, *args, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=222'>223</a> except NotImplementedError:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=223'>224</a>     # don't warn on NotImplementedErrors
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=224'>225</a>     return self._check_return(None, args[0])
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=336'>337</a>     pass
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=337'>338</a> else:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=338'>339</a>     return printer(obj)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=339'>340</a> # Finally look for special method names
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/formatters.py?line=340'>341</a> method = get_real_method(obj, self.print_method)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=147'>148</a>     from matplotlib.backend_bases import FigureCanvasBase
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=148'>149</a>     FigureCanvasBase(fig)
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=150'>151</a> fig.canvas.print_figure(bytes_io, **kw)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=151'>152</a> data = bytes_io.getvalue()
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/IPython/core/pylabtools.py?line=152'>153</a> if fmt == 'svg':
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2296'>2297</a> if bbox_inches:
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2297'>2298</a>     if bbox_inches == "tight":
# -> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2298'>2299</a>         bbox_inches = self.figure.get_tightbbox(
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2299'>2300</a>             renderer, bbox_extra_artists=bbox_extra_artists)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2300'>2301</a>         if pad_inches is None:
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/backend_bases.py?line=2301'>2302</a>             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py:1632, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1628'>1629</a>     artists = bbox_extra_artists
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1630'>1631</a> for a in artists:
# -> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1631'>1632</a>     bbox = a.get_tightbbox(renderer)
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1632'>1633</a>     if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/figure.py?line=1633'>1634</a>         bb.append(bbox)
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py:355, in Artist.get_tightbbox(self, renderer)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=339'>340</a> def get_tightbbox(self, renderer):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=340'>341</a>     """
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=341'>342</a>     Like `.Artist.get_window_extent`, but includes any clipping.
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=342'>343</a>
#    (...)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=352'>353</a>         The enclosing bounding box (in figure pixel coordinates).
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=353'>354</a>     """
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=354'>355</a>     bbox = self.get_window_extent(renderer)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=355'>356</a>     if self.get_clip_on():
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/artist.py?line=356'>357</a>         clip_box = self.get_clip_box()
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/patches.py:623, in Patch.get_window_extent(self, renderer)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/patches.py?line=621'>622</a> def get_window_extent(self, renderer=None):
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/patches.py?line=622'>623</a>     return self.get_path().get_extents(self.get_transform())
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py:626, in Path.get_extents(self, transform, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=623'>624</a> else:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=624'>625</a>     xys = []
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=625'>626</a>     for curve, code in self.iter_bezier(**kwargs):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=626'>627</a>         # places where the derivative is zero can be extrema
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=627'>628</a>         _, dzeros = curve.axis_aligned_extrema()
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=628'>629</a>         # as can the ends of the curve
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py:436, in Path.iter_bezier(self, **kwargs)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=433'>434</a> first_vert = None
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=434'>435</a> prev_vert = None
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=435'>436</a> for verts, code in self.iter_segments(**kwargs):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=436'>437</a>     if first_vert is None:
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=437'>438</a>         if code != Path.MOVETO:
#
# File ~/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py:407, in Path.iter_segments(self, transform, remove_nans, clip, snap, stroke_width, simplify, curves, sketch)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=404'>405</a> extra_vertices = NUM_VERTICES_FOR_CODE[code] - 1
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=405'>406</a> if extra_vertices:
# --> <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=406'>407</a>     for i in range(extra_vertices):
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=407'>408</a>         next(codes)
#     <a href='file:///home/misery7100/GitLibrary/Magistracy/Article-I/.venv/lib/python3.8/site-packages/matplotlib/path.py?line=408'>409</a>         curr_vertices = np.append(curr_vertices, next(vertices))
#
# KeyboardInterrupt:
