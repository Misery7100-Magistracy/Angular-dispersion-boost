# %%
from processing import msevn
import os

msevn.configure_mpl()

# %%
root = './matlab/output/flat'

files = os.listdir(root)

# %%
files[1]
# Out:
# 'cylinder_16edge_2d_relative_83wlen_20radius_0nonreg_15deg_theta0_0deg_phi0_TEpol_83wav_800bw_xz_only.mat'

# %%
xz1 = msevn.MstmEngine(os.path.join(root, files[1]))
fig, ax, bbea = xz1.plot_field(
    trim=20,
    figsize=(10, 10),
    target=dict(plot=False),
    xtick=3000,
    ytick=2000
)
ax.grid(alpha=0.1, color='white')

# %%
xz1.circles
# Out:
#                x       y            z     r
# 0   -3191.147842 -1245.0   597.281718  20.0
# 1   -3148.183880 -1245.0   757.625405  20.0
# 2   -3105.219919 -1245.0   917.969093  20.0
# 3   -3062.255957 -1245.0  1078.312780  20.0
# 4   -3277.075765 -1079.0   276.594344  20.0
# ..           ...     ...          ...   ...
# 635  3363.003688  -747.0    44.093030  20.0
# 636  2847.436150  -581.0 -1880.031216  20.0
# 637  3405.967649  -581.0   204.436718  20.0
# 638  2804.472189  -249.0 -2040.374903  20.0
# 639  3448.931611  -249.0   364.780405  20.0
#
# [640 rows x 4 columns]

# %%
xz0 = msevn.MstmEngine(os.path.join(root, files[0]))
fig, ax, bbea = xz0.plot_field(
    trim=20,
    figsize=(10, 10),
    target=dict(plot=False),
    xtick=3000,
    ytick=2000
)
ax.grid(alpha=0.1, color='white')

# %%
xz2 = msevn.MstmEngine(os.path.join(root, files[2]))
fig, ax, bbea = xz2.plot_field(
    trim=20,
    figsize=(10, 10),
    target=dict(plot=False),
    xtick=3000,
    ytick=2000
)
ax.grid(alpha=0.1, color='white')
