# %%
from misvis.sol import Field2D

f2d = Field2D('../mph/output/83nm_ka0.7_Efull_par.txt')
f2d.plot_var(figsize=(9, 9), trim=0, target={'alpha' : 0.1, 'color' : 'white'})
# Out:
# (<Figure size 648x648 with 2 Axes>,
#  <AxesSubplot:xlabel='$x$, $\\rm{nm}$', ylabel='$z$, $\\rm{nm}$'>)
